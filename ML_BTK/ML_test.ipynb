# %% [markdown]
# ## Real Python Keras

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation
from tensorflow.keras.optimizers import SGD

# %%
x_arr = np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]
])

y_arr = np.array([[0],[1],[1],[0]])

# %%
model = Sequential()
model.add(Dense(2,input_dim=2))
model.add(Activation('sigmoid'))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
sgd = SGD(lr=0.1)
model.compile(loss='mean_squared_error',optimizer=sgd)
model.fit(x_arr,y_arr,batch_size=1,epochs=5000)
# Out:
# Epoch 1/5000
# D:\programs\anaconda3\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 4/4 [==============================] - 0s 2ms/step - loss: 0.3044
# Epoch 2/5000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2991
# Epoch 3/5000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2943
# Epoch 4/5000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2896
# Epoch 5/5000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2854
# Epoch 6/5000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2817
# Epoch 7/5000
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2781
# Epoch 8/5000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2751
# Epoch 9/5000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2724
# Epoch 10/5000
# ...

# %% [markdown]
# ## Tenserflow

# %%
dataset = pd.read_excel('bisiklet_fiyatlari.xlsx')

# %%
dataset.head()
# Out:
#         Fiyat  BisikletOzellik1  BisikletOzellik2
# 0  807.673876       1749.628226       1749.590668
# 1  959.227520       1748.007826       1751.824206
# 2  718.020033       1750.122967       1747.977026
# 3  945.668885       1749.916440       1750.771646
# 4  955.542968       1750.780519       1750.592430

# %%
import tensorflow as ts
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
# X -> features
X = dataset[['BisikletOzellik1','BisikletOzellik2']].values

#Y-> feature
Y = dataset['Fiyat']

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.33,random_state=15)

# scaling

scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# create model
model = Sequential()
model.add(Dense(5,activation='relu'))
model.add(Dense(5,activation='relu'))

model.add(Dense(1))

model.compile(optimizer = 'rmsprop',loss = 'mse')

# %%
 model.fit(X_train,Y_train,epochs=250)
# Out:
# Epoch 1/250
# 21/21 [==============================] - 0s 2ms/step - loss: 795547.9375
# Epoch 2/250
# 21/21 [==============================] - 0s 1ms/step - loss: 795239.0000
# Epoch 3/250
# 21/21 [==============================] - 0s 2ms/step - loss: 794902.4375
# Epoch 4/250
# 21/21 [==============================] - 0s 2ms/step - loss: 794539.6250
# Epoch 5/250
# 21/21 [==============================] - 0s 2ms/step - loss: 794148.0000
# Epoch 6/250
# 21/21 [==============================] - 0s 2ms/step - loss: 793710.3125
# Epoch 7/250
# 21/21 [==============================] - 0s 2ms/step - loss: 793220.1250
# Epoch 8/250
# 21/21 [==============================] - 0s 2ms/step - loss: 792682.0000
# Epoch 9/250
# 21/21 [==============================] - 0s 2ms/step - loss: 792091.6250
# Epoch 10/250
# 21/21 [==============================] - 0s 2ms/step - loss: 791452.7500
# Epoch 11/250
# 21/21 [==============================] - 0s 2ms/step - loss: 790757.9375
# Epoch 12/250
# ...

# %%
loss = model.history.history['loss']

# %%
sns.lineplot(x=range(len(loss)),y=loss)
# Out:
# <AxesSubplot:>

# %%
model.evaluate(X_train,Y_train)
# Out:
# 21/21 [==============================] - 0s 1ms/step - loss: 129.0673
# 129.06732177734375

# %%
model.evaluate(X_test,Y_test)
# Out:
# 11/11 [==============================] - 0s 1ms/step - loss: 123.1097
# 123.1097183227539

# %%
tahmin = model.predict(X_test)
Y_test = np.array(Y_test)
type(Y_test)
# Out:
# numpy.ndarray

# %%
tahmin_data_frame = pd.DataFrame(data=Y_test,columns=['Gercek Y'])

# %%
tahmin_data_frame
# Out:
#         Gercek Y
# 0    1081.652164
# 1     622.675990
# 2     889.356810
# 3     902.826733
# 4     897.662404
# ..           ...
# 325  1028.438035
# 326   789.934950
# 327   758.490486
# 328  1172.871659
# 329   820.947936
#
# [330 rows x 1 columns]

# %%
tahmin = pd.Series(tahmin.reshape(330,))

# %%
son_df = pd.concat([tahmin_data_frame,tahmin],axis=1)

# %%
son_df.columns = ['Gercek Y', 'Tahmini Y']

# %%
son_df
# Out:
#         Gercek Y    Tahmini Y
# 0    1081.652164  1070.059204
# 1     622.675990   635.339783
# 2     889.356810   876.659302
# 3     902.826733   896.169250
# 4     897.662404   901.562927
# ..           ...          ...
# 325  1028.438035  1008.181580
# 326   789.934950   796.755798
# 327   758.490486   770.992981
# 328  1172.871659  1155.413330
# 329   820.947936   808.846680
#
# [330 rows x 2 columns]

# %%
sns.scatterplot(x='Gercek Y',y='Tahmini Y',data=son_df)
# Out:
# <AxesSubplot:xlabel='Gercek Y', ylabel='Tahmini Y'>

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
mean_absolute_error(son_df['Gercek Y'],son_df['Tahmini Y'])
# Out:
# 8.974119920081673

# %%
mean_squared_error(son_df['Gercek Y'],son_df['Tahmini Y'])
# Out:
# 123.1096947965105

# %%
dataset.describe()
# Out:
#              Fiyat  BisikletOzellik1  BisikletOzellik2
# count  1000.000000       1000.000000       1000.000000
# mean    872.677801       1750.024800       1749.964733
# std     164.124504          1.704531          1.659578
# min     390.856887       1744.852108       1744.742389
# 25%     757.795031       1748.831119       1748.803186
# 50%     879.168705       1750.017350       1750.003926
# 75%     988.612778       1751.115765       1751.129414
# max    1355.213745       1755.613884       1754.666038

# %%
yeniBisklit = [[1760,1758]]
yeniBisklit = scaler.transform(yeniBisklit)
yeniBisklit
# Out:
# array([[1.4133144 , 1.34470668]])

# %%
model.predict(yeniBisklit)
# Out:
# array([[1932.4154]], dtype=float32)

# %%
from tensorflow.keras.models import load_model
model.save('bisklit_model.h5')
